# %%
from setup import setup_notebook
setup_notebook()
from spectraldb.utils.io import load_element
from spectraldb.utils.preprocess import preprocess

# %%
load_element("Ag")
# Out:
#      element  sp_num  obs_wl_vac(nm)  unc_obs_wl  ritz_wl_vac(nm)  \
# 0         Ag      47             =""         =""    ="0.04493288"
# 1         Ag      47             =""         =""    ="0.04504874"
# 2         Ag      47             =""         =""    ="0.05299285"
# 3         Ag      47             =""         =""    ="0.05353979"
# 4         Ag      45             =""         =""     ="0.0539078"
# ..       ...     ...             ...         ...              ...
# 734  element  sp_num  obs_wl_vac(nm)  unc_obs_wl  ritz_wl_vac(nm)
# 735       Ag       1       ="3990.0"         =""      ="3989.092"
# 736       Ag       1       ="3990.0"         =""      ="3989.118"
# 737       Ag       1       ="3996.2"         =""      ="3998.820"
# 738       Ag       1       ="3996.2"         =""      ="3998.845"
#
#        unc_ritz_wl  obs-ritz      wn(cm-1)  intens  Aki(10^8 s^-1)  ...  \
# 0    ="0.00000006"       =""  ="222554200"     =""   ="8.0381e+06"  ...
# ...

# %%
load_element("Gold")
# Out:
#     element sp_num obs_wl_vac(nm) unc_obs_wl ritz_wl_vac(nm)    unc_ritz_wl  \
# 0        Au     79            =""        =""   ="0.01484003"  ="0.00000012"
# 1        Au     79            =""        =""   ="0.01495949"  ="0.00000020"
# 2        Au     77            =""        =""   ="0.01714394"  ="0.00000011"
# 3        Au     77            =""        =""   ="0.01715156"  ="0.00000011"
# 4        Au     79            =""        =""   ="0.01732338"  ="0.00000007"
# ..      ...    ...            ...        ...             ...            ...
# 487      Au      1     ="656.268"        =""             =""            =""
# 488      Au      1     ="665.289"        =""             =""            =""
# 489      Au      1     ="751.073"        =""    ="751.0729+"            =""
# 490      Au      1     ="814.506"        =""             =""            =""
# 491      Au      1     ="925.428"        =""             =""            =""
#
# ...

# %%
preprocess("Argon", trimmed=True)
# Out:
#      element  spectrum_number  wavelength_nm  intensity  log10_intensity  \
# 5         Ar               17       0.313700        0.0             -inf
# 8         Ar               17       0.319800       13.0         1.113943
# 9         Ar               17       0.336200       19.0         1.278754
# 40        Ar               18       0.373111       13.0         1.113943
# 42        Ar               18       0.373652        7.0         0.845098
# ...      ...              ...            ...        ...              ...
# 5428      Ar                2    5057.050000        9.0         0.954243
# 5429      Ar                2    5107.727000       10.0         1.000000
# 5430      Ar                2    5130.679500       29.0         1.462398
# 5431      Ar                2    5282.677400       43.0         1.633468
# 5432      Ar                2    5332.841000        5.0         0.698970
#
#       tags  visible
# 5     None    False
# 8     None    False
# 9     None    False
# ...

# %%
from importlib import reload
import spectraldb.utils.preprocess as pp
reload(pp)
import spectraldb.utils.preprocess as pp
pp.preprocess("Zinc", trimmed=True, xyz=True)
# Out:
#     element  spectrum_number  wavelength_nm  intensity  log10_intensity  tags  \
# 118      Zn                4         41.267       30.0         1.477121  None
# 119      Zn                4         42.342       30.0         1.477121  None
# 120      Zn                4         42.354       50.0         1.698970  None
# 121      Zn                4         42.590      200.0         2.301030  None
# 122      Zn                4         42.854      200.0         2.301030  None
# ..      ...              ...            ...        ...              ...   ...
# 940      Zn                1       7409.670     4500.0         3.653213     *
# 941      Zn                1       7466.870       80.0         1.903090     *
# 942      Zn                1       7466.870       80.0         1.903090     *
# 943      Zn                1       7466.870       80.0         1.903090     *
# 944      Zn                1       7466.870       80.0         1.903090     *
#
# ...
