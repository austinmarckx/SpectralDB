# %%
from setup import setup_notebook
setup_notebook()
from importlib import reload

from spectraldb.utils.types import Wavelength, Color
from spectraldb.models.wss import WSS
from spectraldb.utils.io import demo_data
from spectraldb.utils.misc import select_random_wavelengths
from spectraldb.colorspaces import XYZ_to_RGB, RGB_to_XYZ
import spectraldb.colorspaces as cs
reload(cs)
import spectraldb.colorspaces as cs
import spectraldb.utils.types as ty
reload(ty)
import spectraldb.utils.types as ty
import spectraldb.chromaticadaptation as ca
reload(ca)
import spectraldb.chromaticadaptation as ca

import spectraldb.illuminant as ill
argon = demo_data()
argon.head()

illE = ill.get_illuminant("E")
illE

ca.adapt(ill.get_illuminant("A").to_CIE_XYZ(), "B", "vonkries", src_ill="A")
# Out:
# CIE_XYZ(x=np.float64(0.9907200236868112), y=np.float64(0.9999999754545796), z=np.float64(0.8522299819259063), deg=None)

# %%
wave = select_random_wavelengths(argon)
print(wave)
XYZ = WSS.fit(wave)
print(XYZ)

ca.adapt(XYZ, "A", "bradford")
# Out:
# Wavelength(wl=568.148, rgb=None, xyz=None, illuminant=None)
# CIE_XYZ(x=np.float64(0.7423618787716701), y=np.float64(0.9602346269053788), z=np.float64(0.001580589987161467), deg=2)
# CIE_XYZ(x=np.float64(0.9361477682528874), y=np.float64(0.9827593748666216), z=np.float64(0.01834599597011096), deg=2)

# %%
from spectraldb.models.lindbloom import get_working_space
get_working_space("CIE_RGB")
# Out:
# WorkingSpace(name='CIE_RGB', ill='E', M=array([[0.488718 , 0.3106803, 0.2006017],
#        [0.1762044, 0.8129847, 0.0108109],
#        [0.       , 0.0102048, 0.9897952]]), M_inv=array([[ 2.3706743, -0.9000405, -0.4706338],
#        [-0.513885 ,  1.4253036,  0.0885814],
#        [ 0.0052982, -0.0146949,  1.0093968]]), r_xyY=None, g_xyY=None, b_xyY=None)

# %%
xyz = ty.CIE_XYZ(x=0.786800, y=0.944900, z=0.001190)
print(f"xyz: {xyz}")
xyY = cs.XYZ_to_xyY(xyz)
print(f"xyY: {xyY}")
print(f"xyz: {cs.xyY_to_XYZ(xyY)}")
# Out:
# xyz: CIE_XYZ(x=0.7868, y=0.9449, z=0.00119, deg=None)
# xyY: CIE_xyY(x=np.float64(0.45403920618158106), y=np.float64(0.5452740797165428), Y=0.9449)
# xyz: CIE_XYZ(x=np.float64(0.7868), y=0.9449, z=np.float64(0.0011900000000001638), deg=None)

# %%
xyz = ty.CIE_XYZ(x=0.786800, y=0.944900, z=0.001190)
print(f"xyz: {xyz}")
Lab = cs.XYZ_to_Lab(xyz)
print(f"Lab: {Lab}")
LCHab = cs.Lab_to_LCHab(Lab)
print(f"LCHab: {LCHab}")
print(f"Lab(reverse): {cs.LCHab_to_Lab(LCHab)}")
print(f"xyz(rev): {cs.Lab_to_XYZ(Lab)}")
# Out:
# xyz: CIE_XYZ(x=0.7868, y=0.9449, z=0.00119, deg=None)
# Lab: CIE_Lab(L=np.float64(97.8290921757584), a=np.float64(-29.050800132570053), b=np.float64(166.81753376407897), ill='E')
# LCHab: LCHab(L=np.float64(97.8290921757584), C=np.float64(169.32819776833438), H=np.float64(99.87882664448661), ill='E')
# Lab(reverse): CIE_Lab(L=np.float64(97.8290921757584), a=np.float64(-29.050800132570046), b=np.float64(166.81753376407897), ill='E')
# xyz(rev): CIE_XYZ(x=np.float64(0.7867999999999999), y=np.float64(0.9448999999999996), z=np.float64(0.001190000000000004), deg=None)

# %%
xyz = ty.CIE_XYZ(x=0.786800, y=0.944900, z=0.001190)
print(f"xyz: {xyz}")
Luv = cs.XYZ_to_Luv(xyz)
print(f"Luv: {Luv}")
LCHuv = cs.Luv_to_LCHuv(Luv)
print(f"LCHuv: {LCHuv}")
print(f"Lab(reverse): {cs.LCHab_to_Lab(LCHuv)}")
print(f"xyz(rev): {cs.Luv_to_XYZ(Luv)}")
# Out:
# xyz: CIE_XYZ(x=0.7868, y=0.9449, z=0.00119, deg=None)
# Luv: Luv(L=np.float64(97.8290921757584), u=np.float64(-0.2624846755458372), v=np.float64(120.34157464448306), ill='E')
# LCHuv: LCHuv(L=np.float64(97.8290921757584), C=np.float64(120.3418609051671), H=np.float64(90.12497127688826), ill='E')
# Lab(reverse): CIE_Lab(L=np.float64(97.8290921757584), a=np.float64(-0.26248467554584315), b=np.float64(120.34157464448306), ill='E')
# xyz(rev): CIE_XYZ(x=np.float64(0.7867999999999998), y=np.float64(0.9448999999999996), z=np.float64(0.0011900000000002464), deg=None)

# %%
from spectraldb.models.lindbloom import create_working_space
r_xyY = ty.CIE_xyY(x=0.6400, y=0.3300, Y=0.2126)
g_xyY = ty.CIE_xyY(x=0.3000, y=0.6000, Y=0.7152)
b_xyY = ty.CIE_xyY(x=0.1500, y=0.0600, Y=0.0722)

create_working_space("sRGB", r_xyY, g_xyY, b_xyY, "D65")
# Out:
# WorkingSpace(name='sRGB', ill='D65', M=array([[0.41245644, 0.35757608, 0.18043748],
#        [0.21267285, 0.71515216, 0.07217499],
#        [0.0193339 , 0.11919203, 0.95030408]]), M_inv=array([[ 3.24045416, -1.53713851, -0.49853141],
#        [-0.96926603,  1.87601085,  0.04155602],
#        [ 0.05564343, -0.20402591,  1.05722519]]), r_xyY=CIE_xyY(x=0.64, y=0.33, Y=0.2126), g_xyY=CIE_xyY(x=0.3, y=0.6, Y=0.7152), b_xyY=CIE_xyY(x=0.15, y=0.06, Y=0.0722))

# %%
import spectraldb.utils.types as ty
reload(ty)
import spectraldb.utils.types as ty
import spectraldb.colorspaces as cs
reload(cs)
import spectraldb.colorspaces as cs

cs.make_elemental_workingspace("Li")
cs.make_elemental_colorscale("Li")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\models\lindbloom.py:284, in get_working_space(ws)
#     283 try:
# --> 284     return WORKING_SPACES_DICT[ws]
#     285 except:
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 9
#       6 import spectraldb.colorspaces as cs
#       8 cs.make_elemental_workingspace("Li")
# ----> 9 cs.make_elemental_colorscale("Li")
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:52, in make_elemental_colorscale(el, elworkspace, space)
#      49     space=make_elemental_workingspace(el)
#      51 df = pd.concat([ filter_visible(preprocess(e, trimmed=True, xyz=True))for e in el], axis=0, ignore_index=True)
# ---> 52 cs = set([v[1] for v in make_colorscale(df.reset_index(drop=True).sort_values(by="wavelength_nm"), space=space)])
#      53 cs = [v.tostr() for v in sorted(map(Color.totuple, cs), key=lambda t: (t[0], t[1], t[2]) ) ]
#      54 #cs = [v.tostr() for v in sorted(map(Color.totuple, cs), key=lambda t: (sum(t), t[0], t[1], t[2]) ) ]
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:62, in make_colorscale(df, norm_col, color_col, space)
#      60     df[norm_col] = normalize_wavelength(df)
#      61 if color_col not in df.columns:
# ---> 62     df[color_col] = add_color_col(df, space=space)
#      64 func = lambda idx: {
#      65     "lower":df[norm_col][idx-1] if idx > 1 else 0.,
#      66     "upper":df[norm_col][idx],
#    (...)     69     "b":df[color_col][idx][2],
#      70 }
#      71 colorscale = sorted(set(chain.from_iterable([ ColorRange(**func(i)).to_colorscale() for i in range(1, df.shape[0])] ) ))
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:88, in add_color_col(df, xcol, ycol, zcol, deg, space, **kwargs)
#      86 def add_color_col(df:pd.DataFrame, xcol:str="x", ycol:str="y", zcol:str="z", deg:Optional[Literal["2","10"]]=None, space:NamedWorkingSpace="CIE_RGB", **kwargs) -> list[RGBTuple]:
#      87     func = lambda x,y,z: XYZ_to_color(CIE_XYZ(x,y,z,deg=deg), space)[0]
# ---> 88     return [func(x,y,z) for x,y,z in zip(df[xcol], df[ycol], df[zcol])]
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:87, in add_color_col.<locals>.<lambda>(x, y, z)
#      86 def add_color_col(df:pd.DataFrame, xcol:str="x", ycol:str="y", zcol:str="z", deg:Optional[Literal["2","10"]]=None, space:NamedWorkingSpace="CIE_RGB", **kwargs) -> list[RGBTuple]:
# ---> 87     func = lambda x,y,z: XYZ_to_color(CIE_XYZ(x,y,z,deg=deg), space)[0]
#      88     return [func(x,y,z) for x,y,z in zip(df[xcol], df[ycol], df[zcol])]
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:100, in XYZ_to_color(val, space)
#      99 def XYZ_to_color(val:CIE_XYZ, space:NamedWorkingSpace="CIE_RGB") -> Color:
# --> 100     return RGB_to_Color(XYZ_to_RGB(val, space))
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\colorspaces.py:234, in XYZ_to_RGB(val, space)
#     232 def XYZ_to_RGB(val:CIE_XYZ, space:NamedWorkingSpace="CIE_RGB") -> RGB:
#     233     if not isinstance(space, WorkingSpace):
# --> 234         space = get_working_space(space)
#     235     rgb = (val.to_numpy() @ space.M_inv).tolist()
#     236     return RGB(rgb[0], rgb[1], rgb[2])
#
# File c:\Users\s184945\Desktop\spectraldb\spectraldb\models\lindbloom.py:286, in get_working_space(ws)
#     284     return WORKING_SPACES_DICT[ws]
#     285 except:
# --> 286     raise ValueError(f"{ws} is not a recognized working space")
#
# ValueError: WorkingSpace(name='Li', ill='E', M=array([[-0.21765058,  0.52191489,  0.69573569],
#        [-1.01485915,  0.3488327 ,  1.66602645],
#        [-1.04604493,  1.86786139,  0.17818353]]), M_inv=array([[ 2.50723396, -0.99191108, -0.51532288],
#        [ 1.28406157, -0.56642563,  0.28236406],
#        [ 1.25842339,  0.11460667, -0.37303007]]), r_xyY=CIE_xyY(x=np.float64(0.09552133263157896), y=np.float64(0.4453960089473684), Y=84.6252417), g_xyY=CIE_xyY(x=np.float64(0.19057663636363636), y=np.float64(0.12737586818181817), Y=53.2431129), b_xyY=CIE_xyY(x=np.float64(0.2739175471698113), y=np.float64(0.6559299549865228), Y=243.3500133)) is not a recognized working space

# %%
cs.XYZ_to_color(XYZ)

# %%
from spectraldb.models.lindbloom import WORKING_SPACES_DICT
WORKING_SPACES_DICT
# Out:
# {'Adobe_RGB_1998': WorkingSpace(name='Adobe_RGB_1998', ill='D65', M=array([[0.5767309, 0.185554 , 0.1881852],
#         [0.2973769, 0.6273491, 0.0752741],
#         [0.0270343, 0.0706872, 0.9911085]]), M_inv=array([[ 2.041369 , -0.5649464, -0.3446944],
#         [-0.969266 ,  1.8760108,  0.041556 ],
#         [ 0.0134474, -0.1183897,  1.0154096]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'AppleRGB': WorkingSpace(name='AppleRGB', ill='D65', M=array([[0.4497288, 0.3162486, 0.1844926],
#         [0.2446525, 0.6720283, 0.0833192],
#         [0.0251848, 0.1411824, 0.9224628]]), M_inv=array([[ 2.9515373, -1.2894116, -0.4738445],
#         [-1.0851093,  1.9908566,  0.0372026],
#         [ 0.0854934, -0.2694964,  1.0912975]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'Best_RGB': WorkingSpace(name='Best_RGB', ill='D50', M=array([[0.6326696, 0.2045558, 0.1269946],
#         [0.2284569, 0.7373523, 0.0341908],
#         [0.       , 0.0095142, 0.8156958]]), M_inv=array([[ 1.7552599, -0.4836786, -0.253    ],
#         [-0.5441336,  1.5068789,  0.0215528],
#         [ 0.0063467, -0.0175761,  1.2256959]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'Beta_RGB': WorkingSpace(name='Beta_RGB', ill='D50', M=array([[0.6712537, 0.1745834, 0.1183829],
#         [0.3032726, 0.6637861, 0.0329413],
#         [0.       , 0.040701 , 0.784509 ]]), M_inv=array([[ 1.683227 , -0.4282363, -0.2360185],
#         [-0.7710229,  1.7065571,  0.04469  ],
#         [ 0.0400013, -0.0885376,  1.272364 ]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'Bruce_RGB': WorkingSpace(name='Bruce_RGB', ill='D65', M=array([[0.4674162, 0.2944512, 0.1886026],
#         [0.2410115, 0.6835475, 0.075441 ],
#         [0.0219101, 0.0736128, 0.9933071]]), M_inv=array([[ 2.7454669, -1.1358136, -0.4350269],
#         [-0.969266 ,  1.8760108,  0.041556 ],
#         [ 0.0112723, -0.1139754,  1.0132541]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'CIE_RGB': WorkingSpace(name='CIE_RGB', ill='E', M=array([[0.488718 , 0.3106803, 0.2006017],
#         [0.1762044, 0.8129847, 0.0108109],
#         [0.       , 0.0102048, 0.9897952]]), M_inv=array([[ 2.3706743, -0.9000405, -0.4706338],
#         [-0.513885 ,  1.4253036,  0.0885814],
#         [ 0.0052982, -0.0146949,  1.0093968]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'ColorMatch_RGB': WorkingSpace(name='ColorMatch_RGB', ill='D50', M=array([[0.5093439, 0.3209071, 0.1339691],
#         [0.274884 , 0.6581315, 0.0669845],
#         [0.0242545, 0.1087821, 0.6921735]]), M_inv=array([[ 2.6422874, -1.223427 , -0.3930143],
#         [-1.1119763,  2.0590183,  0.0159614],
#         [ 0.0821699, -0.2807254,  1.4559877]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'Don_RGB_4': WorkingSpace(name='Don_RGB_4', ill='D50', M=array([[0.6457711, 0.1933511, 0.1250978],
#         [0.2783496, 0.6879702, 0.0336802],
#         [0.0037113, 0.0179861, 0.8035125]]), M_inv=array([[ 1.7603902, -0.4881198, -0.2536126],
#         [-0.7126288,  1.6527432,  0.0416715],
#         [ 0.0078207, -0.0347411,  1.2447743]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'ECI_RGB': WorkingSpace(name='ECI_RGB', ill='D50', M=array([[0.6502043, 0.1780774, 0.1359384],
#         [0.3202499, 0.6020711, 0.0776791],
#         [0.       , 0.067839 , 0.757371 ]]), M_inv=array([[ 1.7827618, -0.4969847, -0.2690101],
#         [-0.9593623,  1.9477962, -0.0275807],
#         [ 0.0859317, -0.1744674,  1.3228273]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'Ekta_Space_PS5': WorkingSpace(name='Ekta_Space_PS5', ill='D50', M=array([[0.5938914, 0.2729801, 0.0973485],
#         [0.2606286, 0.7349465, 0.0044249],
#         [0.       , 0.0419969, 0.7832131]]), M_inv=array([[ 2.0043819, -0.7304844, -0.2450052],
#         [-0.7110285,  1.6202126,  0.0792227],
#         [ 0.0381263, -0.086878 ,  1.2725438]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'NTSC_RGB': WorkingSpace(name='NTSC_RGB', ill='C', M=array([[0.6068909, 0.1735011, 0.200348 ],
#         [0.2989164, 0.586599 , 0.1144845],
#         [0.       , 0.0660957, 1.1162243]]), M_inv=array([[ 1.9099961, -0.5324542, -0.2882091],
#         [-0.9846663,  1.999171 , -0.0283082],
#         [ 0.0583056, -0.1183781,  0.8975535]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'PAL_SECAM_RGB': WorkingSpace(name='PAL_SECAM_RGB', ill='D65', M=array([[0.430619 , 0.3415419, 0.1783091],
#         [0.2220379, 0.7066384, 0.0713236],
#         [0.0201853, 0.1295504, 0.9390944]]), M_inv=array([[ 3.0628971, -1.3931791, -0.4757517],
#         [-0.969266 ,  1.8760108,  0.041556 ],
#         [ 0.0678775, -0.2288548,  1.069349 ]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'ProPhoto_RGB': WorkingSpace(name='ProPhoto_RGB', ill='D50', M=array([[7.976749e-01, 1.351917e-01, 3.135340e-02],
#         [2.880402e-01, 7.118741e-01, 8.570000e-05],
#         [0.000000e+00, 0.000000e+00, 8.252100e-01]]), M_inv=array([[ 1.3459433, -0.2556075, -0.0511118],
#         [-0.5445989,  1.5081673,  0.0205351],
#         [ 0.       ,  0.       ,  1.2118128]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'SMPTE_C_RGB': WorkingSpace(name='SMPTE_C_RGB', ill='D65', M=array([[0.3935891, 0.3652497, 0.1916313],
#         [0.2124132, 0.7010437, 0.0865432],
#         [0.0187423, 0.1119313, 0.9581563]]), M_inv=array([[ 3.505396 , -1.7394894, -0.543964 ],
#         [-1.0690722,  1.9778245,  0.0351722],
#         [ 0.05632  , -0.1970226,  1.0502026]]), r_xyY=None, g_xyY=None, b_xyY=None),
#  'sRGB': WorkingSpace(name='sRGB', ill='D65', M=array([[0.4124564, 0.3575761, 0.1804375],
#         [0.2126729, 0.7151522, 0.072175 ],
#         [0.0193339, 0.119192 , 0.9503041]]), M_inv=array([[ 3.2404542, -1.5371385, -0.4985314],
#         [-0.969266 ,  1.8760108,  0.041556 ],
#         [ 0.0556434, -0.2040259,  1.0572252]]), r_xyY=CIE_xyY(x=0.64, y=0.33, Y=0.2126), g_xyY=CIE_xyY(x=0.3, y=0.6, Y=0.7152), b_xyY=CIE_xyY(x=0.15, y=0.06, Y=0.0722)),
#  'Wide_Gamut_RGB': WorkingSpace(name='Wide_Gamut_RGB', ill='D50', M=array([[0.7161046, 0.1009296, 0.1471858],
#         [0.2581874, 0.7249378, 0.0168748],
#         [0.       , 0.0517813, 0.7734287]]), M_inv=array([[ 1.4628067, -0.1840623, -0.2743606],
#         [-0.5217933,  1.4472381,  0.0677227],
#         [ 0.0349342, -0.096893 ,  1.2884099]]), r_xyY=None, g_xyY=None, b_xyY=None)}
