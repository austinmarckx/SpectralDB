# %%
from setup import setup_notebook
setup_notebook()
import pandas as pd
from importlib import reload
from spectraldb.utils.types import Wavelength, Color
from spectraldb.models.wss import WSS
from spectraldb.utils.io import demo_data
from spectraldb.utils.misc import select_random_wavelengths
import spectraldb.colorspaces as cs
reload(cs)
import spectraldb.colorspaces as cs
from spectraldb.illuminant import get_illuminant
from spectraldb.models.lindbloom import get_working_space
argon = demo_data()
argon.head()

wave = select_random_wavelengths(argon)
print(wave)

XYZ = WSS.fit(wave)
print(XYZ)
# Out:
# Wavelength(wl=66.1869, rgb=None, xyz=None, illuminant=None)
# CIE_XYZ(x=np.float64(8.508046599871804e-44), y=np.float64(1.0637788504674343e-25), z=np.float64(1.4738742020302926e-50), deg=2)

# %%
get_working_space()

print(XYZ)
srgb = cs.XYZ_to_RGB(XYZ)
print(srgb)
print(cs.RGB_to_XYZ(srgb))
print(cs.RGB_to_Color(srgb))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(XYZ)
#       2 srgb = cs.XYZ_to_RGB(XYZ)
#       3 print(srgb)
#
# NameError: name 'XYZ' is not defined

# %%
import spectraldb.utils.types as ty
reload(ty)
import spectraldb.utils.types as ty

v = sorted(map(Color.totuple, cs.make_elemental_colorscale("Li")), key=lambda t: (sum(t), t[0], t[1], t[2]) )
print(v)
# Out:
# [RGBA(r=0.0, g=0.0, b=0.0, a=1.0), RGBA(r=1.0, g=0.0, b=6.0, a=1.0), RGBA(r=5.0, g=0.0, b=12.0, a=1.0), RGBA(r=41.0, g=0.0, b=0.0, a=1.0), RGBA(r=44.0, g=0.0, b=70.0, a=1.0), RGBA(r=0.0, g=103.0, b=87.0, a=1.0), RGBA(r=0.0, g=60.0, b=132.0, a=1.0), RGBA(r=255.0, g=0.0, b=0.0, a=1.0), RGBA(r=115.0, g=255.0, b=0.0, a=1.0), RGBA(r=117.0, g=255.0, b=0.0, a=1.0), RGBA(r=119.0, g=0.0, b=255.0, a=1.0), RGBA(r=123.0, g=0.0, b=255.0, a=1.0), RGBA(r=144.0, g=0.0, b=255.0, a=1.0), RGBA(r=163.0, g=0.0, b=255.0, a=1.0), RGBA(r=184.0, g=0.0, b=255.0, a=1.0)]
