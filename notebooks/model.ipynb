# %%
from setup import setup_notebook
setup_notebook()
import pandas as pd
from importlib import reload
from spectraldb.utils.types import Wavelength
from spectraldb.models.wss import WSS
from spectraldb.utils.io import demo_data
from spectraldb.utils.misc import select_random_wavelengths
from spectraldb.colorspaces import XYZ_to_sRGB, sRGB_to_XYZ

argon = demo_data()
argon.head()

wave = select_random_wavelengths(argon)
print(wave)

XYZ = WSS.fit(wave)
print(XYZ)
# Out:
# Wavelength(wl=1032.534, srgb=None, xyz=None, illuminant=None)
# CIE_XYZ(x=np.float64(3.987142963365937e-43), y=np.float64(2.659253306896208e-29), z=np.float64(3.6821221253337014e-60), deg=2)

# %%
import spectraldb.colorspaces as cs
reload(cs)
import spectraldb.colorspaces as cs

print(XYZ)
srgb = cs.XYZ_to_sRGB(XYZ)
print(srgb)
print(cs.sRGB_to_XYZ(srgb))
print(cs.sRGB_to_Color(srgb))
# Out:
# CIE_XYZ(x=np.float64(0.8408061622712307), y=np.float64(0.9210655511665702), z=np.float64(0.0008336586082825323), deg=2)
# sRGB(r=1.5138418793583106, g=0.559496458676068, b=-0.31063296598829526)
# CIE_XYZ(x=0.8408133940712362, y=0.9210552738448365, z=0.0008367041300105238, deg=2)
# Color(rgb=(255, 143, 0))
