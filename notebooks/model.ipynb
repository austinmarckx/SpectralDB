# %%
from setup import setup_notebook
setup_notebook()

import pandas as pd
from spectraldb.utils.preprocess import preprocess
from spectraldb.utils.types import Wavelength
from spectraldb.models.wss import WSS

argon = preprocess("Argon", True)
argon.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from utils.preprocess import preprocess
#       3 from utils.types import Wavelength
# ----> 4 from models.wss import WSS
#       6 argon = preprocess("Argon", True)
#       7 argon.head()
#
# File c:\Users\s184945\Desktop\spectraldb\src\models\wss.py:16
#      14 import numpy as np
#      15 from typing import Literal, Union
# ---> 16 from src.utils.types import CIE_XYZ, Wavelength
#      17 from src.utils.defaults import LRU_CACHE_SIZE
#      18 from functools import lru_cache
#
# ModuleNotFoundError: No module named 'src'

# %%
# Out:
#      element  spectrum_number  wavelength_nm  intensity  log10_intensity  tags
# 117        Y                7        15.7364       10.0         1.000000  None
# 119        Y                7        16.1789      100.0         2.000000  None
# 120        Y                7        16.1967     6000.0         3.778151  None
# 121        Y                7        16.2798      500.0         2.698970  None
# 122        Y                7        16.2901      400.0         2.602060  None
# ...      ...              ...            ...        ...              ...   ...
# 1594       Y                3       864.5090     4000.0         3.602060  None
# 1595       Y                3       879.6210    10000.0         4.000000  None
# 1596       Y                1       880.0590       95.0         1.977724  None
# 1597       Y                2       883.5875       19.0         1.278754     h
# 1598       Y                3       911.6590     8000.0         3.903090  None
#
# [1441 rows x 6 columns]

# %% [markdown]
# # TODO: Database
# 1) Create SQL Table to hold cleaned elements
# 2) Insert all cleaned elements into SQL table
# 3) Search functionalities for Table

# %% [markdown]
# # TODO: Visualization
#
# Play around with and figure out how to represent the spectral lines as images
#
# --> element(s) to colormap
#
# https://engineering.purdue.edu/~bouman/ece637/notes/pdf/Tristimulus.pdf
#     • CIE 1931 Standard 2
# – R, G, B color primaries are defined by pure line spectra (delta functions in wavelength) at 700nm, 546.1nm,
# and 435.8nm.
#
# let's start with D65 whitepoint. or illuminant E
#
# http://www.cvrl.org/database/text/intros/introcmfs.htm
#
# O_O
# https://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_E
# https://en.wikipedia.org/wiki/CIE_1931_color_space#Tristimulus_values
# https://en.wikipedia.org/wiki/RGB_color_spaces
