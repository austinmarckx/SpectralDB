# %%
from setup import setup_notebook
setup_notebook()
import pandas as pd
from importlib import reload

from spectraldb.utils.types import CIE_XYZ
from spectraldb.utils.misc import minmaxnorm
import spectraldb.utils.io as io
import spectraldb.spectraldensity as sd
import spectraldb.colorspaces as cs
import spectraldb.utils.types as ty

# %%
import spectraldb.spectraldensity as sd
reload(sd)
import spectraldb.spectraldensity as sd

sd.spectral_density(["Zinc", "Argon", "Uranium"])

# %%
import spectraldb.spectraldensity as sd
reload(sd)
import spectraldb.spectraldensity as sd

sd.visible_spectral_density(["Zinc", "Argon", "Uranium"], bin_size=10)

# %%
import spectraldb.colorspaces as cs
reload(cs)
import spectraldb.colorspaces as cs


ref = io.load_cie_reference(refdeg="2006_deg2")
ref
# colorscale = cs.make_colorscale(ref)
# colorscale
# Out:
#       wavelength_nm         x             y         z
# 0             390.0  0.003770  4.146161e-04  0.018473
# 1             390.1  0.003840  4.227277e-04  0.018816
# 2             390.2  0.003911  4.309905e-04  0.019166
# 3             390.3  0.003984  4.394068e-04  0.019523
# 4             390.4  0.004058  4.479791e-04  0.019886
# ...             ...       ...           ...       ...
# 4396          829.6  0.000002  7.217496e-07  0.000000
# 4397          829.7  0.000002  7.176201e-07  0.000000
# 4398          829.8  0.000002  7.135165e-07  0.000000
# 4399          829.9  0.000002  7.094385e-07  0.000000
# 4400          830.0  0.000002  7.053860e-07  0.000000
#
# [4401 rows x 4 columns]

# %%
import spectraldb.spectraldensity as sd
reload(sd)
import spectraldb.spectraldensity as sd

sd.heatmap(["Zn", "Ar"], colorscale="reference")

# %%
import spectraldb.spectraldensity as sd
reload(sd)
import spectraldb.spectraldensity as sd

sd.heatmap(["Zn", "Ar"], colorscale="reference")

# %% [markdown]
# # TODO: Visualization
#
# Play around with and figure out how to represent the spectral lines as images
#
# --> element(s) to colormap
#
# https://engineering.purdue.edu/~bouman/ece637/notes/pdf/Tristimulus.pdf
#     • CIE 1931 Standard 2
# – R, G, B color primaries are defined by pure line spectra (delta functions in wavelength) at 700nm, 546.1nm,
# and 435.8nm.
#
# let's start with D65 whitepoint. or illuminant E
# https://www.color.org/chardata/colorimetry/index.xalter
#
# http://www.cvrl.org/database/text/intros/introcmfs.htm
#
# O_O
# https://en.wikipedia.org/wiki/Standard_illuminant#Illuminant_E
# https://en.wikipedia.org/wiki/CIE_1931_color_space#Tristimulus_values
# https://en.wikipedia.org/wiki/RGB_color_spaces
