# %%
import pandas as pd
import sqlite3 as sql
from utils.io import load_element

# %%
He = load_element("Rb")
He
# Out:
#      element sp_num obs_wl_vac(nm) unc_obs_wl ritz_wl_vac(nm)     unc_ritz_wl  \
# 0         Rb     37            =""        =""  ="0.066723492"  ="0.000000008"
# 1         Rb     37            =""        =""  ="0.067227449"  ="0.000000009"
# 2         Rb     37            =""        =""  ="0.068060820"  ="0.000000009"
# 3         Rb     37            =""        =""  ="0.068082087"  ="0.000000012"
# 4         Rb     37            =""        =""  ="0.069674630"  ="0.000000014"
# ...      ...    ...            ...        ...             ...             ...
# 2700      Rb      1    ="2732.176"   ="0.001"     ="2732.180"        ="0.011"
# 2701      Rb      1    ="2791.298"   ="0.001"     ="2791.292"        ="0.011"
# 2702      Rb      1    ="3993.462"   ="0.008"     ="3993.486"        ="0.023"
# 2703      Rb      1    ="3993.462"   ="0.008"     ="3993.444"        ="0.023"
# 2704      Rb      1    ="3993.462"   ="0.008"     ="3993.444"        ="0.023"
#
# ...
