# %%
import pandas as pd
import sqlite3 as sql
from defaults import RAW_LINES_PATH, SPECTRALDB_ABS_PATH
from utils.io import system_agnostic_pathjoin as pthjoin
hydrogen_path = pthjoin("H.csv", RAW_LINES_PATH)

# %%
#print(SPECTRALDB_ABS_PATH)
print(hydrogen_path)
H = pd.read_csv(hydrogen_path)
# Out:
# c:\Users\s184945\Desktop\spectraldb\data\raw\lines\wavelength\H.csv
