# %%
import pandas as pd
import sqlite3 as sql
from utils.io import load_element
from preprocess import preprocess, _subset

# %%
Zn = load_element("Zinc")
print(Zn.columns)
# Out:
# Index(['element', 'sp_num', 'obs_wl_vac(nm)', 'unc_obs_wl', 'ritz_wl_vac(nm)',
#        'unc_ritz_wl', 'obs-ritz', 'wn(cm-1)', 'intens', 'Aki(10^8 s^-1)',
#        'fik', 'S(a.u.)', 'log_gf', 'Acc', 'Ei(cm-1)', 'Ek(cm-1)', 'conf_i',
#        'term_i', 'J_i', 'conf_k', 'term_k', 'J_k', 'g_i', 'g_k', 'Type',
#        'tp_ref', 'line_ref'],
#       dtype='object')

# %%
df = _subset(preprocess("Xe"))
df
# Out:
#      element spectrum_number wavelength intensity  log10_intensity tags
# 0         Xe              54                 None              NaN  NaN
# 1         Xe              54                 None              NaN  NaN
# 2         Xe              54   0.039639      None              NaN  NaN
# 3         Xe              52                 None              NaN  NaN
# 4         Xe              52                 None              NaN  NaN
# ...      ...             ...        ...       ...              ...  ...
# 5799      Xe               1    5444.72         4          0.60206
# 5800      Xe               1                 None              NaN  NaN
# 5801      Xe               1                 None              NaN  NaN
# 5802      Xe               1    11297.0      None              NaN  NaN
# 5803      Xe               1    18514.0      None              NaN  NaN
#
# [5802 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.fillna()
#
# File c:\Users\s184945\AppData\Local\pypoetry\Cache\virtualenvs\spectraldb-U_BKntVM-py3.13\Lib\site-packages\pandas\core\generic.py:7316, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7309         if ctr <= ref_count:
#    7310             warnings.warn(
#    7311                 _chained_assignment_warning_method_msg,
#    7312                 FutureWarning,
#    7313                 stacklevel=2,
#    7314             )
# -> 7316 value, method = validate_fillna_kwargs(value, method)
#    7317 if method is not None:
#    7318     warnings.warn(
#    7319         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7320         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)   7323         stacklevel=find_stack_level(),
#    7324     )
#
# File c:\Users\s184945\AppData\Local\pypoetry\Cache\virtualenvs\spectraldb-U_BKntVM-py3.13\Lib\site-packages\pandas\util\_validators.py:293, in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     290 from pandas.core.missing import clean_fill_method
#     292 if value is None and method is None:
# --> 293     raise ValueError("Must specify a fill 'value' or 'method'.")
#     294 if value is None and method is not None:
#     295     method = clean_fill_method(method)
#
# ValueError: Must specify a fill 'value' or 'method'.

# %% [markdown]
# # TODO: Database
# 1) Create SQL Table to hold cleaned elements
# 2) Insert all cleaned elements into SQL table
# 3) Search functionalities for Table

# %% [markdown]
# # TODO: Visualization
#
# Play around with and figure out how to represent the spectral lines as images
#
# --> element(s) to colormap
