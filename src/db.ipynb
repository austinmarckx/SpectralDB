# %%
import pandas as pd
import sqlite3 as sql
from utils.io import load_element
from utils.preprocess import preprocess

# %%
RAW_LINES_PATH

# %%
Zn = load_element("Zinc")
print(Zn.columns)

# %%
df = preprocess("He")
sdf = preprocess("He", trimmed=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 df = preprocess("He")
# ----> 2 sdf = preprocess("He", trimmed=True)
#
# File c:\Users\s184945\Desktop\spectraldb\src\utils\preprocess.py:126, in preprocess(el, trimmed)
#     123     df['intens_tags'] = tmp[0] + tmp[2]
#     125 if trimmed:
# --> 126     return trim(df)
#     127 return df
#
# File c:\Users\s184945\Desktop\spectraldb\src\utils\preprocess.py:146, in trim(df)
#     144 df = _subset_rename(df)
#     145 df = df.dropna(subset=["wavelength_nm","intensity"])
# --> 146 df = _type_conversion(df)
#     147 return df
#
# File c:\Users\s184945\Desktop\spectraldb\src\utils\preprocess.py:157, in _type_conversion(df, mapping)
#     155     if type(ty) == str:
#     156         df[col].replace("", None, inplace=True)
# --> 157     df[col] = df[col].astype(ty)
#     158 return df
#
# ...

# %%
df
# Out:
#      element sp_num obs_wl_vac(nm) unc_obs_wl ritz_wl_vac(nm)   unc_ritz_wl  \
# 0         He      2                             23.4347160426  0.0000000005
# 1         He      2                             23.4347279561  0.0000000005
# 2         He      2                             23.7330663920  0.0000000005
# 3         He      2                             23.7330875061  0.0000000005
# 4         He      2                             24.3026444338  0.0000000005
# ...      ...    ...            ...        ...             ...           ...
# 2437      He      1                                1352848.09          0.05
# 2438      He      1                                1353353.63          0.05
# 2439      He      1                                1837655.81          0.10
# 2440      He      1                                 2356231.4           0.4
# 2441      He      1                                 3225773.7           0.7
#
# ...

# %% [markdown]
# # TODO: Database
# 1) Create SQL Table to hold cleaned elements
# 2) Insert all cleaned elements into SQL table
# 3) Search functionalities for Table

# %% [markdown]
# # TODO: Visualization
#
# Play around with and figure out how to represent the spectral lines as images
#
# --> element(s) to colormap
